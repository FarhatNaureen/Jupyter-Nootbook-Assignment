# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Farhat Naureen** <br> Educationist and Researcher

# %% [markdown]
# *My interest in data science was developed during my PhD. Because I worked with big biological data throughout my PhD.*

# %% [markdown]
# ### My code in Cell 5 will print the product of two numbers.

# %%
print(3*7)
# Out:
# 21

# %% [markdown]
# ***
#
# - First bulleted list's item <br>
# - Second bulleted list's item <br>
# - Third bulleted list's item <br>
# <br>
#
# 1. First numbered list's item <br>
# 2. Second numbered list's item <br>
# 3. Third numbered list's item
#
# | Name | Age | Gender |
# | :- | :-: | :- |
# | Sara | 33 | Female |
# | Adam | 25 | Male |
# <br>
#
# Link for a popular search engine (www.google.com)
#
# ![image.png](attachment:94e9faff-b3db-4248-80d3-87f3d861f533.png)
#
# ~Strikethrough text~
